# %%
import unsullied
# Out:
# Epochs: 100%|█████████████████████████████████████████████████| 300/300 [00:04<00:00, 68.68it/s, loss=0.080, acc=0.993]

# %%
unsullied.time_to_serve()
# Out:
# Unsullied: Valar Morghulis, Master! I was born to serve you!
# ********************************************************************************
# Master: Hey, discover papers about parse trees
# Unsullied: Master, I'll search with new context.
# Unsullied: There are 115 scrolls in our library, Master. I brought a few:
#
# [0.] Quasi-polynomial Hitting Sets for Circuits with Restricted Parse Trees. Ramprasad Saptharishi, Anamay Tengse. 2017.
#
# [1.] Training Deep Capsule Networks. David Peer, Sebastian Stabinger, Antonio Rodriguez-Sanchez. 2018.
#
# [2.] A Computational Interpretation of Context-Free Expressions. Martin Sulzmann, Peter Thiemann. 2017.
#
# [3.] Grammar Specialization through Entropy Thresholds. Christer Samuelsson. 1994.
#
# [4.] Identifiability and Unmixing of Latent Parse Trees. Daniel Hsu, Sham M. Kakade, Percy Liang. 2012.
#
# [5.] Compositional Distributional Semantics with Long Short Term Memory. Phong Le, Willem Zuidema. 2015.
#
# ...
